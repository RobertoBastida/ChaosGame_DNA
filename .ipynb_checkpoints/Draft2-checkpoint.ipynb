# %% [markdown]
# <center><h1>Dimensión fractal en diferentes conjuntos</h1></center>
#
# El presente notebook tiene por objetivo ilustrar la ejecución de las funciones desarrolladas para el cálculo de la dimensión fractal para subconjunto de $\mathbb{R}^{2}$.

# %%
import sys
sys.path.insert(0, "Scripts")

from libraries import *
from fractal_dimension import *

# %% [markdown]
# ## Comparación entre conteo de cajas y dimensión topológica
#
# Para verificar que las funciones se comporten correctamente; las probamos primero con dos conjuntos arquetípicos: una línea recta y un cuadrado.
#
# Consideramos válidas las funciones para el cálculo de la dimensión a partir del algoritmo de Minkowski-Bouling si es que éstas arrojaran las dimensiones iguales a 1.0 y 2.0 para los conjuntos antes mencionados, respectimante.

# %%
length = 1000000

# %% [markdown]
# ## Recta
#
# Generación de una recta con 1,000,000 puntos.

# %%
line_x = np.linspace(0,1,length)
line_y = [0.5 for x in line_x]

# %%
plt.scatter(line_x,line_y,s=0.00005)
plt.axis('equal')
plt.axis('off')
plt.savefig("ilustraciones/plot/Otros/{}".format("recta"),dpi=150)

# %%
Line_dimension = Frac_dimension_computation_name(line_x,line_y,"Recta")
# Out:
# coefficient (fractal dimension) = 1.0

# %% [markdown]
# ## Cuadrado
#
# Generación de puntos aleatorios dentro de un cuadrado

# %%
# La generación de los puntos aleatorios
rec_coordinates = np.random.rand(length,2)

# Seleccionamos las x,y como listas
rec_x = rec_coordinates[:,0]
rec_y = rec_coordinates[:,1]

# %%
# Graficamos para visualizar el conjunto
plt.scatter(rec_x,rec_y,s=0.00005)
plt.axis('equal')
plt.axis('off')
plt.savefig("ilustraciones/plot/Otros/{}".format("cuadrado"),dpi=150)

# %%
Square_dimension = Frac_dimension_computation_name(rec_x,rec_y,"Cuadrado")
# Out:
# coefficient (fractal dimension) = 2.0

# %% [markdown]
# # Juego del caos
#
# Probamos ahora el correcto funcionamiento de las librerías desarrolladas específicamente para medir la dimensión fractal de conjuntos generados a partir del juego del caos en dos diferentes escenarios: El triángulo de Sierpinski

# %%
sier_x,sier_y = SFI.Sierpinski_coordinates(Iteraciones=length)

# %%
plt.scatter(sier_x,sier_y,s=0.00005)
#plt.axis('equal')
plt.axis('off')
plt.savefig("ilustraciones/plot/Otros/{}".format("sierpinski"),dpi=150)

# %%
Sierpinski_dimension = Frac_dimension_computation_name(sier_x,sier_y,"Sierpinski")
# Out:
# coefficient (fractal dimension) = 1.6721652201416348

# %%
line_r_x = sorted(sier_x)
line_r_y = [0.5 + 1*(np.random.rand()) for x in line_r_x]

# %%
plt.scatter(line_r_x,line_r_y,s=0.00005)
plt.axis('equal')
plt.axis('off')
plt.savefig("ilustraciones/plot/Otros/{}".format("barcode"),dpi=150)

# %%
Barcode_dimension = Frac_dimension_computation_name(line_r_x,line_r_y,"ilustraciones/dim/Otros/Barcode")
# Out:
# coefficient (fractal dimension) = 1.9119016144773127
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-837bded0dc21> in <module>
# ----> 1 Barcode_dimension = Frac_dimension_computation_name(line_r_x,line_r_y,"ilustraciones/dim/Otros/Barcode")
#
# /run/media/robertobastidaluna/30F8F86FF8F83526/Files/BackUp_Roberto/Titulación/ServicioSocial/Proyecto/Scripts/fractal_dimension.py in Frac_dimension_computation_name(equis, ye, name)
#     153         plt.ylabel("log(N ($\epsilon$))")
#     154         plt.title(name)
# --> 155         plt.savefig("ilustraciones/dim/{}".format(name),dpi=150)
#     156         plt.show()
#     157         plt.clf()
#
# ~/.conda/envs/Generic/lib/python3.8/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     841 def savefig(*args, **kwargs):
#     842     fig = gcf()
# --> 843     res = fig.savefig(*args, **kwargs)
#     844     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     845     return res
#
# ~/.conda/envs/Generic/lib/python3.8/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# ~/.conda/envs/Generic/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2208
#    2209             try:
# -> 2210                 result = print_method(
#    2211                     filename,
#    2212                     dpi=dpi,
#
# ~/.conda/envs/Generic/lib/python3.8/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# ~/.conda/envs/Generic/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     508         """
#     509         FigureCanvasAgg.draw(self)
# --> 510         mpl.image.imsave(
#     511             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     512             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/.conda/envs/Generic/lib/python3.8/site-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1599         pil_kwargs.setdefault("format", format)
#    1600         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1601         image.save(fname, **pil_kwargs)
#    1602
#    1603
#
# ~/.conda/envs/Generic/lib/python3.8/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2153                 fp = builtins.open(filename, "r+b")
#    2154             else:
# -> 2155                 fp = builtins.open(filename, "w+b")
#    2156
#    2157         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ilustraciones/dim/ilustraciones/dim/Otros/Barcode.png'

# %% [markdown]
# ## Genoma humano
#
# Se emula el juego del caos con el genoma humano a basándonos en las ideas de <u>artículo</u>

# %%
Dic_1 = {'A':(0,0),'C':(1,0),'T':(1,1),'G':(0,1)}
# Dic_2 es el del ejemplo del reporte
Dic_2 = {'A':(0,0),'C':(1,0),'G':(1,1),'T':(0,1)}
Dic_3 = {'A':(0,0),'T':(1,0),'C':(1,1),'G':(0,1)}
Dic_4 = {'A':(0,0),'T':(1,0),'G':(1,1),'C':(0,1)}
Dic_5 = {'A':(0,0),'G':(1,0),'C':(1,1),'T':(0,1)}
Dic_6 = {'A':(0,0),'G':(1,0),'T':(1,1),'C':(0,1)}

DIC = [Dic_1,Dic_2,Dic_3,Dic_4,Dic_5,Dic_6]

# %%
Chr = "chr_19.txt"
Str_Chr = load_txt_file("data/",Chr)

# trimming the string to a length of maximum 1,000,000 nucleotides
CG_Chr = chaos_game_chromosome(Str_Chr[0:min(len(Str_Chr),length)],Dic_2)

# grabbing the coordinates
CG_x = [i[0] for i in CG_Chr]
CG_y = [i[1] for i in CG_Chr]

# Plotting 
plt.scatter(CG_x,CG_y,s=0.0000125)
plt.axis('equal')
plt.axis('off')
plt.savefig("ilustraciones/plot/ch19/{}".format(Chr),dpi=200)
plt.show()
plt.clf()

Chr_19_Fd = Frac_dimension_computation(CG_x,CG_y)

# %%
Chr = "chr_21.txt"
Str_Chr = load_txt_file("data/",Chr)

# trimming the string to a length of maximum 1,000,000 nucleotides
CG_Chr = chaos_game_chromosome(Str_Chr[0:min(len(Str_Chr),length)],Dic_2)

# grabbing the coordinates
CG_x = [i[0] for i in CG_Chr]
CG_y = [i[1] for i in CG_Chr]

plt.scatter(CG_x,CG_y,s=0.0000125)
plt.axis('equal')
plt.axis('off')
plt.savefig("ilustraciones/plot/ch21//{}".format(Chr),dpi=200)
plt.show()
plt.clf()

Chr_19_Fd = Frac_dimension_computation(CG_x,CG_y)

# %% [markdown]
# ## Emulando distribuciones de nucleótidos

# %%
Str_Chr = random_nuc(length)
chr_20_dimension = []
# trimming the string to a length of maximum 1,000,000 nucleotides
CG_Chr = chaos_game_chromosome(Str_Chr[0:min(len(Str_Chr),length)],Dic_2)

# grabbing the coordinates
CG_x = [i[0] for i in CG_Chr]
CG_y = [i[1] for i in CG_Chr]

plt.scatter(CG_x,CG_y,s=0.0000125)
plt.axis('equal')
plt.axis('off')
plt.show()
plt.clf()

Chr_20_Fd = Frac_dimension_computation(CG_x,CG_y)
chr_20_dimension.append(Chr_20_Fd[-1])
