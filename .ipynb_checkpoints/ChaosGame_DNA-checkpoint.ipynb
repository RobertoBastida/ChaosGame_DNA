# %% [markdown]
# <center>Dimensión fractal en diferentes conjuntos</center>
#
# El presente notebook tiene por objetivo ilustrar la ejecución de las funciones desarrolladas para el cálculo de la dimensión fractal para subconjunto de $\mathbb{R}^{2}$.

# %%
import sys
sys.path.insert(0, "Scripts")

from libraries import *
from fractal_dimension import *

# %%
os.getcwd()
# Out:
# '/run/media/robertobastidaluna/30F8F86FF8F83526/Files/BackUp_Roberto/Titulación/ServicioSocial/Proyecto'

# %% [markdown]
# ## Comparación entre conteo de cajas y dimensión topológica
#
# Para verificar que las funciones se comporten correctamente; las probamos primero con dos conjuntos arquetípicos: una línea recta y un cuadrado.
#
# Consideramos válidas las funciones para el cálculo de la dimensión a partir del algoritmo de Minkowski-Bouling si es que éstas arrojaran las dimensiones iguales a 1.0 y 2.0 para los conjuntos antes mencionados, respectimante.

# %%
length = 250000

# %% [markdown]
# ## Recta
#
# Generación de una recta con 1,000,000 puntos.

# %%
line_x = np.linspace(0,1,length)
line_y = [0.5 for x in line_x]

# %%
plt.scatter(line_x,line_y,s=0.00005)
plt.axis('equal')
plt.axis('off')
plt.savefig("ilustraciones/plot/{}".format("recta"),dpi=150)

# %%
Frac_dimension_computation_name(line_x,line_y,"Recta")
# Out:
# coefficient (fractal dimension) = 1.0
# ([1.3862943611198906,
#   2.0794415416798357,
#   2.772588722239781,
#   3.4657359027997265,
#   4.1588830833596715,
#   4.852030263919617,
#   5.545177444479562],
#  [1.3862943611198906,
#   2.0794415416798357,
#   2.772588722239781,
#   3.4657359027997265,
#   4.1588830833596715,
#   4.852030263919617,
#   5.545177444479562],
#  1.0)

# %% [markdown]
# ## Cuadrado
#
# Generación de puntos aleatorios dentro de un cuadrado

# %%
# La generación de los puntos aleatorios
rec_coordinates = np.random.rand(length,2)

# Seleccionamos las x,y como listas
rec_x = rec_coordinates[:,0]
rec_y = rec_coordinates[:,1]

# %%
# Graficamos para visualizar el conjunto
plt.scatter(rec_x,rec_y,s=0.00005)
plt.axis('equal')
plt.axis('off')
plt.savefig("ilustraciones/plot/{}".format("cuadrado"),dpi=150)

# %%
Square_dimension = Frac_dimension_computation_name(rec_x,rec_y,"Cuadrado")
# Out:
# coefficient (fractal dimension) = 1.9965416005118906

# %% [markdown]
# # Juego del caos
#
# Probamos ahora el correcto funcionamiento de las librerías desarrolladas específicamente para medir la dimensión fractal de conjuntos generados a partir del juego del caos en dos diferentes escenarios: El triángulo de Sierpinski

# %%
sier_x,sier_y = SFI.Sierpinski_coordinates(Iteraciones=length)

# %%
plt.scatter(sier_x,sier_y,s=0.00005)
#plt.axis('equal')
plt.axis('off')
plt.savefig("ilustraciones/plot/{}".format("sierpinski"),dpi=150)

# %%
Sierpinski_dimension = Frac_dimension_computation_name(sier_x,sier_y,"Sierpinski")
# Out:
# coefficient (fractal dimension) = 1.6695446506027498

# %%
line_r_x = sorted(sier_x)
line_r_y = [0.5 + 1*(np.random.rand()) for x in line_r_x]

# %%
plt.scatter(line_r_x,line_r_y,s=0.00005)
plt.axis('equal')
plt.axis('off')
plt.savefig("ilustraciones/plot/{}".format("barcode"),dpi=150)

# %%
Barcode_dimension = Frac_dimension_computation_name(line_r_x,line_r_y,"Código de barras")
# Out:
# coefficient (fractal dimension) = 1.9390633287147245

# %% [markdown]
# ## Genoma humano
#
# Se emula el juego del caos con el genoma humano a basándonos en las ideas de <u>artículo</u>

# %%
Dic_1 = {'A':(0,0),'C':(1,0),'T':(1,1),'G':(0,1)}
# Dic_2 es el del ejemplo del reporte
Dic_2 = {'A':(0,0),'C':(1,0),'G':(1,1),'T':(0,1)}
Dic_3 = {'A':(0,0),'T':(1,0),'C':(1,1),'G':(0,1)}
Dic_4 = {'A':(0,0),'T':(1,0),'G':(1,1),'C':(0,1)}
Dic_5 = {'A':(0,0),'G':(1,0),'C':(1,1),'T':(0,1)}
Dic_6 = {'A':(0,0),'G':(1,0),'T':(1,1),'C':(0,1)}

DIC = [Dic_1,Dic_2,Dic_3,Dic_4,Dic_5,Dic_6]

# %%
Chr = "chr_19.txt"
Str_Chr = load_txt_file("data/",Chr)

# trimming the string to a length of maximum 1,000,000 nucleotides
CG_Chr = chaos_game_chromosome(Str_Chr[0:min(len(Str_Chr),length)],Dic_1)

# grabbing the coordinates
CG_x = [i[0] for i in CG_Chr]
CG_y = [i[1] for i in CG_Chr]

# Plotting 
plt.scatter(CG_x,CG_y,s=0.0000125)
plt.axis('equal')
plt.axis('off')
plt.show()
plt.clf()

Chr_19_Fd = Frac_dimension_computation(CG_x,CG_y)
# Out:
# coefficient (fractal dimension) = 1.9608762287268007

# %%
Chr = "chr_19.txt"
Str_Chr = load_txt_file("data/",Chr)

# trimming the string to a length of maximum 1,000,000 nucleotides
CG_Chr = chaos_game_chromosome(Str_Chr[0:min(len(Str_Chr),length)],Dic_2)

# grabbing the coordinates
CG_x = [i[0] for i in CG_Chr]
CG_y = [i[1] for i in CG_Chr]

plt.scatter(CG_x,CG_y,s=0.0000125)
plt.axis('equal')
plt.axis('off')
plt.show()
plt.clf()

Chr_19_Fd = Frac_dimension_computation(CG_x,CG_y)
# Out:
# coefficient (fractal dimension) = 1.960870270722303

# %%
Chr = "chr_19.txt"
Str_Chr = load_txt_file("data/",Chr)

# trimming the string to a length of maximum 1,000,000 nucleotides
CG_Chr = chaos_game_chromosome(Str_Chr[0:min(len(Str_Chr),length)],Dic_3)

# grabbing the coordinates
CG_x = [i[0] for i in CG_Chr]
CG_y = [i[1] for i in CG_Chr]

plt.scatter(CG_x,CG_y,s=0.0000125)
plt.axis('equal')
plt.axis('off')
plt.show()
plt.clf()

Chr_19_Fd = Frac_dimension_computation(CG_x,CG_y)
# Out:
# coefficient (fractal dimension) = 1.9608643124881482

# %%
Chr = "chr_19.txt"
Str_Chr = load_txt_file("data/",Chr)
chr_19_dimension = []
for d in DIC:
    # trimming the string to a length of maximum 1,000,000 nucleotides
    CG_Chr = chaos_game_chromosome(Str_Chr[0:min(len(Str_Chr),length)],d)

    # grabbing the coordinates
    CG_x = [i[0] for i in CG_Chr]
    CG_y = [i[1] for i in CG_Chr]

    plt.scatter(CG_x,CG_y,s=0.0000125)
    plt.axis('equal')
    plt.axis('off')
    plt.show()
    plt.clf()

    Chr_19_Fd = Frac_dimension_computation(CG_x,CG_y)
    chr_19_dimension.append(Chr_19_Fd[-1])
# Out:
# coefficient (fractal dimension) = 1.9608762287268007
# coefficient (fractal dimension) = 1.960870270722303
# coefficient (fractal dimension) = 1.9608643124881482
# coefficient (fractal dimension) = 1.9608672916339338
# coefficient (fractal dimension) = 1.9608732497532586
# coefficient (fractal dimension) = 1.9608821865016588

# %% [markdown]
# ## Chr 20

# %%
Chr = "chr_20.txt"
Str_Chr = load_txt_file("data/",Chr)

# trimming the string to a length of maximum 1,000,000 nucleotides
CG_Chr = chaos_game_chromosome(Str_Chr[0:min(len(Str_Chr),length)],Dic_1)

# grabbing the coordinates
CG_x = [i[0] for i in CG_Chr]
CG_y = [i[1] for i in CG_Chr]

# %%
plt.scatter(CG_x,CG_y,s=0.0000125)
plt.axis('equal')
plt.axis('off')
# Out:
# (-0.05, 1.05, -0.04999999999987872, 1.0499999999974554)

# %%
Chr_20_Fd = Frac_dimension_computation(CG_x,CG_y)
# Out:
# coefficient (fractal dimension) = 1.9608762287268007

# %%
Chr = "chr_21.txt"
Str_Chr = load_txt_file("data/",Chr)
chr_20_dimension = []
for d in DIC:
    # trimming the string to a length of maximum 1,000,000 nucleotides
    CG_Chr = chaos_game_chromosome(Str_Chr[0:min(len(Str_Chr),length)],d)

    # grabbing the coordinates
    CG_x = [i[0] for i in CG_Chr]
    CG_y = [i[1] for i in CG_Chr]

    plt.scatter(CG_x,CG_y,s=0.0000125)
    plt.axis('equal')
    plt.axis('off')
    plt.show()
    plt.clf()

    Chr_20_Fd = Frac_dimension_computation(CG_x,CG_y)
    chr_20_dimension.append(Chr_20_Fd[-1])
# Out:
# coefficient (fractal dimension) = 1.9608762287268007
# coefficient (fractal dimension) = 1.960870270722303
# coefficient (fractal dimension) = 1.9608643124881482
# coefficient (fractal dimension) = 1.9608672916339338
# coefficient (fractal dimension) = 1.9608732497532586
# coefficient (fractal dimension) = 1.9608821865016588

# %% [markdown]
# ## Verificando diferencias entre variantes
#
# Para medir la similitud entre dos mediciones usamos el MAPE, una métrica muy usual para medir la precisión de pronósticos en <i>análisis de series de tiempo</i>.
#
# $$MAPE = \frac{1}{n} \sum_{o}^{n}{\frac{|y_{o} - y_{i}|}{y_{o}}}$$

# %%
for i,j in zip(chr_19_dimension,chr_20_dimension):
    print(i,j)
    print(error(i,j))
# Out:
# 1.9608762287268007 1.9608762287268007
# 0.0
# 1.960870270722303 1.960870270722303
# 0.0
# 1.9608643124881482 1.9608643124881482
# 0.0
# 1.9608672916339338 1.9608672916339338
# 0.0
# 1.9608732497532586 1.9608732497532586
# 0.0
# 1.9608821865016588 1.9608821865016588
# 0.0

# %% [markdown]
# ## Emulando distribuciones de nucleótidos

# %%
Str_Chr = random_nuc(length)
chr_20_dimension = []
for d in DIC:
    # trimming the string to a length of maximum 1,000,000 nucleotides
    CG_Chr = chaos_game_chromosome(Str_Chr[0:min(len(Str_Chr),length)],d)

    # grabbing the coordinates
    CG_x = [i[0] for i in CG_Chr]
    CG_y = [i[1] for i in CG_Chr]

    plt.scatter(CG_x,CG_y,s=0.0000125)
    plt.axis('equal')
    plt.axis('off')
    plt.show()
    plt.clf()

    Chr_20_Fd = Frac_dimension_computation(CG_x,CG_y)
    chr_20_dimension.append(Chr_20_Fd[-1])
# Out:
# coefficient (fractal dimension) = 1.9966501017461358
# coefficient (fractal dimension) = 1.9966428706994863
# coefficient (fractal dimension) = 1.9966501017461358
# coefficient (fractal dimension) = 1.9966597426154986
# coefficient (fractal dimension) = 1.9966428706994863
# coefficient (fractal dimension) = 1.996647691434838

# %%
Str_Chr = random_nuc(length)
chr_random_dimension = []
for d in DIC:
    # trimming the string to a length of maximum 1,000,000 nucleotides
    CG_Chr = chaos_game_chromosome(Str_Chr[0:min(len(Str_Chr),length)],d)

    # grabbing the coordinates
    CG_x = [i[0] for i in CG_Chr]
    CG_y = [i[1] for i in CG_Chr]

    plt.scatter(CG_x,CG_y,s=0.0000125)
    plt.axis('equal')
    plt.axis('off')
    plt.show()
    plt.clf()

    Chr_random_Fd = Frac_dimension_computation(CG_x,CG_y)
    chr_random_dimension.append(Chr_random_Fd[-1])
# Out:
# coefficient (fractal dimension) = 1.9965512481506817
# coefficient (fractal dimension) = 1.9965488362974348
# coefficient (fractal dimension) = 1.9965536599662967
# coefficient (fractal dimension) = 1.9965536599662967
# coefficient (fractal dimension) = 1.9965536599662967
# coefficient (fractal dimension) = 1.9965536599662967

# %%
from collections import Counter

# %%
"""bias = string_dist(Str_Chr)
Str_Chr = random_nuc(length,bias=bias)
chr_biased_dimension = []
for d in DIC:
    # trimming the string to a length of maximum 1,000,000 nucleotides
    CG_Chr = chaos_game_chromosome(Str_Chr[0:min(len(Str_Chr),length)],bias)

    # grabbing the coordinates
    CG_x = [i[0] for i in CG_Chr]
    CG_y = [i[1] for i in CG_Chr]

    plt.scatter(CG_x,CG_y,s=0.0000125)
    plt.axis('equal')
    plt.axis('off')
    plt.show()
    plt.clf()

    Chr_biased_Fd = Frac_dimension_computation(CG_x,CG_y)
    chr_biased_dimension.append(Chr_biased_Fd[-1])"""
# Out:
# "bias = string_dist(Str_Chr)\nStr_Chr = random_nuc(length,bias=bias)\nchr_biased_dimension = []\nfor d in DIC:\n    # trimming the string to a length of maximum 1,000,000 nucleotides\n    CG_Chr = chaos_game_chromosome(Str_Chr[0:min(len(Str_Chr),length)],bias)\n\n    # grabbing the coordinates\n    CG_x = [i[0] for i in CG_Chr]\n    CG_y = [i[1] for i in CG_Chr]\n\n    plt.scatter(CG_x,CG_y,s=0.0000125)\n    plt.axis('equal')\n    plt.axis('off')\n    plt.show()\n    plt.clf()\n\n    Chr_biased_Fd = Frac_dimension_computation(CG_x,CG_y)\n    chr_biased_dimension.append(Chr_biased_Fd[-1])"

# %%
def invert_dic(dic):
    return dict(zip(dic.values(),dic.keys()))

# %%
type(invert_dic(bias))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-9a89f1f90190> in <module>
# ----> 1 type(invert_dic(bias))
#
# NameError: name 'bias' is not defined

# %%
invert_dic(bias)

# %%
def cumulative_list(LIST):
    assert LIST == sorted(LIST), "Lista debe estar ordenada"
    cumulative_list = [[0,LIST[0]]]
    for i in range(1,len(LIST)):
        cumulative_list.append([1+cumulative_list[-1][1],cumulative_list[-1][1]+LIST[i]])
        
    return cumulative_list

# %%
cumulative_list([1,2,3,4,5,6])

# %%
sort_dict_values(invert_dic(bias),rev=False,by='keys')

# %%
sort_dict_values(invert_dic(bias),rev=False,by='keys').keys()

# %%
A = cumulative_list(list(sort_dict_values(invert_dic(bias),rev=False,by='keys').keys()))

# %%
A

# %%
sort_dict_values(invert_dic(bias),rev=False).keys()

# %%
def interval_picker(value,lista):
    assert value < lista[-1][1], "valor"
    crit = False
    initial = 0
    while not crit:
        if lista[initial][0] < value < lista[initial][1]:
            crit = True
        else:
            initial += 1
    return initial

# %%
interval_picker(np.random.randint(1,A[-1][1]),A)

# %%
Rand = np.random.randint(1,A[-1][1])

# %%
Rand

# %%
list(sort_dict_values(invert_dic(bias),rev=False,by='keys').values())[interval_picker(Rand,A)]
